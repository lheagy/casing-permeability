# %% [markdown]
# # EM casing response dipole source

# %%
import numpy as np
import scipy.sparse as sp
import pandas as pd
from scipy.constants import mu_0
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, LinearSegmentedColormap, Normalize
from matplotlib import cm as colormap
import time
from string import ascii_lowercase
import pickle
from multiprocessing import Pool

# SimPEG, discretize/
import discretize
from discretize import utils
from SimPEG.electromagnetics import frequency_domain as fdem
from SimPEG import(
    maps, Report, data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils
)
from pymatsolver import Pardiso

# casing utility code 
import casingSimulations as casing_sim

# %%
path_to_data = "/t40array/lheagy/casing-permeability"

# %%
from matplotlib import rcParams
rcParams["font.size"] = 16

# %%
save_figures = False
fig_dir_high = "figures"
fig_dir_low = "low-rez-figures"

dpi_high=400
dpi_low=150

# %% [markdown]
# ## Simulation parameters

# %%
directory = f"{path_to_data}/fields_dipole_fdem"

# %%
frequencies = np.load(f"{directory}/frequencies.npy")
mesh = discretize.load_mesh(f"{directory}/mesh.json")
models = pickle.load(open(f"{directory}/models.pkl", "rb"))

# %%
# # conductivities
sigma_air = 1e-4
sigma_back = 1e-1
sigma_casing = 5e6
# mur_casing = np.r_[1, 50, 100, 150, 200]

# # casing geometry
casing_b = 5e-2  
casing_t = np.r_[5e-3, 7.5e-3, 10e-3, 12.5e-3, 15e-3, 20e-3]
casing_l = 500

# %%
# # diffusion distance
# 1260 * np.sqrt(1/sigma_back)

# %%
src_dz = 10
src_z = np.r_[-100, -250, -400, -495, -500, -550, -600]

# %%
ax = mesh.plot_grid()

# %%
def get_casing_inds(ca):
    inds_casing_x = (
        (mesh.cell_centers[:, 0] > ca) & 
        (mesh.cell_centers[:, 0] < casing_b)
    )
    inds_casing_z = (
        (mesh.cell_centers[:, 2] < 0) &
        (mesh.cell_centers[:, 2] > -casing_l)
    )
    return inds_casing_x & inds_casing_z

# %%
def plot_casing(ax, model): 
    xlim = 0.22*np.r_[-1, 1]
    zlim = np.r_[-700, 50]
    pcolor_opts={"norm":LogNorm(), "cmap":"Spectral_r"}
    out = casing_sim.view.plot_slice(
        mesh, model, pcolor_opts=pcolor_opts, ax=ax,
    )
    # out[-1].set_label("conductivity (S/m)")
    ax.set_xlim(xlim)
    ax.set_ylim(zlim)

    ax.set_xlabel("x (m)")
    ax.set_ylabel("z (m)")
    return ax

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 7))

key = "conductive_casing_2.50e+08_2.00e-02"

plot_casing(ax, models[key]["sigma"])

for loc in src_z:
    ax.plot(np.r_[0, 0], loc + src_dz/2*np.r_[-1, 1], "-k", lw=4, alpha=0.5)
# Out:
# /home/lheagy/git/simpeg/discretize/discretize/base/base_tensor_mesh.py:1025: FutureWarning: hx has been deprecated, please access as mesh.h[0]
#   warnings.warn(
# /home/lheagy/git/simpeg/discretize/discretize/base/base_tensor_mesh.py:1059: FutureWarning: hz has been deprecated, please access as mesh.h[2]
#   warnings.warn(
# /home/lheagy/git/simpeg/discretize/discretize/utils/code_utils.py:140: FutureWarning: CylMesh has been deprecated, please use CylindricalMesh. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# /home/lheagy/git/simpeg/discretize/discretize/utils/code_utils.py:182: FutureWarning: CylindricalMesh.isSymmetric has been deprecated, please use CylindricalMesh.is_symmetric. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# /home/lheagy/git/simpeg/discretize/discretize/utils/code_utils.py:217: FutureWarning: CylMesh.plotImage has been deprecated, please use CylMesh.plot_image. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(

# %% [markdown]
# ## set up the simulations

# %%
def generate_simulation(mur):
    src_list = []
    for loc in src_z:
        src_locations = np.array([
            [0, 0, loc+src_dz/2.],
            [0, 0, loc-src_dz/2.]
        ])
        for f in frequencies: 
            src = fdem.sources.LineCurrent([], location=src_locations, frequency=f)
            src_list.append(src)
        
    survey = fdem.Survey(src_list)
    sim = fdem.simulation.Simulation3DMagneticField(
        mesh=mesh, sigmaMap=maps.IdentityMap(mesh),
        survey=survey, solver=Pardiso, mu=mur * mu_0
    #     verbose=True
    )
    return sim

# %%
def load_fields(name, conductivity, mur):
    solution = np.load(f"{directory}/fields_{name}.npy")
    sim = generate_simulation(mur)
    sim.model = conductivity
    f = sim.fieldsPair(sim)
    f[:, sim._solutionType] = solution
    return f

# %% [markdown]
# # choose models to focus on

# %%
len(frequencies)
# Out:
# 41

# %%
casing_t_inv = np.r_[10e-3]
mur_inv = np.r_[1, 50, 100, 150, 200]
freq_inds_inv = np.arange(0, 31, 1)
# freq_inds_inv = np.arange(0, 22, 1)
src_ind_inv = 5

inv_keys = []
for t in casing_t_inv:
    for mur in mur_inv:
        inv_keys.append(f"casing_{mur}_{t:1.2e}")
inv_keys
# Out:
# ['casing_1_1.00e-02',
#  'casing_50_1.00e-02',
#  'casing_100_1.00e-02',
#  'casing_150_1.00e-02',
#  'casing_200_1.00e-02']

# %%
frequencies[freq_inds_inv]
# Out:
# array([  0.1       ,   0.12589254,   0.15848932,   0.19952623,
#          0.25118864,   0.31622777,   0.39810717,   0.50118723,
#          0.63095734,   0.79432823,   1.        ,   1.25892541,
#          1.58489319,   1.99526231,   2.51188643,   3.16227766,
#          3.98107171,   5.01187234,   6.30957344,   7.94328235,
#         10.        ,  12.58925412,  15.84893192,  19.95262315,
#         25.11886432,  31.6227766 ,  39.81071706,  50.11872336,
#         63.09573445,  79.43282347, 100.        ])

# %%
fields = {}
for key in inv_keys:
    # if key not in fields.keys():
    fields[key] = load_fields(key, models[key]["sigma"], models[key]["mur"])
# Out:
# /home/lheagy/git/simpeg/discretize/discretize/utils/code_utils.py:182: FutureWarning: CylindricalMesh.edgeCurl has been deprecated, please use CylindricalMesh.edge_curl. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)

# %%
rcParams["font.size"] = 13

# %%
fields.keys()
# Out:
# dict_keys(['casing_1_1.00e-02', 'casing_50_1.00e-02', 'casing_100_1.00e-02', 'casing_150_1.00e-02', 'casing_200_1.00e-02'])

# %%
def skin_depth(f, sigma, mur):
    return np.sqrt(2/(2*np.pi*f*sigma*mur*mu_0))

# %%
rx_x = np.linspace(100, 500, 17)
rx_z = np.r_[-mesh.h[2].min()/2]

# %%
def create_receivers():
    rx_e_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="real",
    )
    rx_e_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="imag",
    )
    return rx_e_re, rx_e_im

# %%
rx_e_re, rx_e_im = create_receivers()
P = rx_e_re.getP(mesh, "Fx")
# Out:
# /home/lheagy/git/simpeg/discretize/discretize/utils/code_utils.py:217: FutureWarning: CylindricalMesh.getInterpolationMat has been deprecated, please use CylindricalMesh.get_interpolation_matrix. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(

# %%
k = inv_keys[0]
field = fields[k][:, "e"]
# Out:
# /home/lheagy/git/simpeg/discretize/discretize/base/base_tensor_mesh.py:1042: FutureWarning: hy has been deprecated, please access as mesh.h[1]
#   warnings.warn(
# /home/lheagy/git/simpeg/discretize/discretize/utils/code_utils.py:182: FutureWarning: CylindricalMesh.area has been deprecated, please use CylindricalMesh.face_areas. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)
# /home/lheagy/git/simpeg/discretize/discretize/utils/code_utils.py:182: FutureWarning: CylindricalMesh.vol has been deprecated, please use CylindricalMesh.cell_volumes. It will be removed in version 1.0.0 of discretize.
#   warnings.warn(message, Warning)

# %%
# get data_vectors
dobs_dict = {}

for k in inv_keys:
    field = fields[k][:, "e"]
    tmp_dict = {}
    for indf in freq_inds_inv:
        si = src_ind_inv*len(frequencies) + indf
        e = field[:, si]
        edata = P * e
        tmp_dict[frequencies[indf]] = {
            "real": edata.real,
            "imag": edata.imag
        }
    dobs_dict[k] = tmp_dict

# %%
def plot_pos_neg_log(x, y, ax, plot_type="semilogy", ls=None, color=None, marker=None, label=None):
    if plot_type == "plot":
        return ax.plot(x, y, color=color, label=label)
    else:
        inds_pos = (y > 0)
        
        inds_switch = np.where(np.diff(inds_pos))[0].astype(int)+1
        starting_inds = np.hstack([np.r_[0], inds_switch])
        ending_inds = np.hstack([inds_switch, np.r_[len(inds_pos)]])
        
        if ls is None:
            pos_ls = "-"
            neg_ls = "--"
        else:
            pos_ls = "-."
            neg_ls = ":"
        
        if marker is True: 
            marker_pos = "o"
            marker_neg = "s"
        else: 
            marker_pos = None
            marker_neg = None
            
        for start, end in zip(starting_inds, ending_inds):
            xvals = x[start:end]
            yvals = y[start:end]
            if np.all(yvals <= 0):
                getattr(ax, plot_type)(xvals, np.abs(yvals), neg_ls, marker=marker_neg, color=color)
            else: 
                getattr(ax, plot_type)(xvals, yvals, pos_ls, marker=marker_pos, color=color, label=label)
                label=None
        return ax

# %%
fig, ax = plt.subplots(len(freq_inds_inv), 2, figsize=(10, len(freq_inds_inv)*3), sharex=True)

for i, key in enumerate(inv_keys):
    dobs = dobs_dict[key]
    for j, freq in enumerate(dobs.keys()):
        dobs_freq = dobs[freq]
        for k, reim in enumerate(dobs_freq.keys()):
            label = f"{key.split('_')[1]} $\mu_0$"
            plot_pos_neg_log(
                rx_x, dobs_freq[reim], ax[j, k], marker=True, color=f"C{i}", label=label, plot_type="semilogy"
            )
            ax[j, k].grid("both", alpha=0.5)
            ax[j, k].set_title(f"{freq} Hz {reim}")
ax[0, 0].legend()

# %% [markdown]
# # set up mappings and simulation

# %%
def create_maps(true_inds=False, casing_t_ind=0):
    indsx = (mesh.cell_centers[:, 0] < casing_b)
    if true_inds is True: 
        indsx = indsx & (mesh.cell_centers[:, 0] > casing_b - casing_t[casing_t_ind])
    
    inds_interior = (
        indsx &
        (mesh.cell_centers[:, 2] <= 0) &
        (mesh.cell_centers[:, 2] >= -casing_l)
    )

    active_inds_sigma = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=np.log(models[inv_keys[0]]["sigma"][~inds_interior])
    )

    active_inds_mur = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=models[inv_keys[0]]["mur"][~inds_interior]
    )

    projection_sigma = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])
    projection_mu = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])

    exp_map = maps.ExpMap(mesh)
    mur_map = maps.MuRelative(mesh)

    sigma_map = exp_map * active_inds_sigma * projection_sigma
    mu_map = mur_map * active_inds_mur * projection_mu

    return sigma_map, mu_map

# %%
def create_survey(freq): 
    loc = src_z[src_ind_inv]
    src_locations = np.array([
        [0, 0, loc+src_dz/2.],
        [0, 0, loc-src_dz/2.]
    ])

    rx_e_re, rx_e_im = create_receivers()
    src = fdem.sources.LineCurrent([rx_e_re, rx_e_im], location=src_locations, frequency=freq)
    return fdem.Survey([src])

# %%
# create the simulation
def create_simulation(survey, invert_mu=True, true_inds=False):
    wires = maps.Wires(("sigma", 1), ("mu", 1))
    sigma_map, mu_map = create_maps(true_inds)

    if invert_mu is True: 
        sim = fdem.simulation.Simulation3DCurrentDensity(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map * wires.sigma,
            muMap=mu_map * wires.mu 
        )
    else: 
        sim = fdem.simulation.Simulation3DCurrentDensity(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map
        )
    return sim

# %% [markdown]
# # set up inversions

# %%
class SaveInversionProgress(directives.InversionDirective):
    """
    A custom directive to save items of interest during the course of an inversion
    """
    
    results_file = None
    
    def initialize(self):
        """
        This is called when we first start running an inversion
        """
        # initialize an empty dictionary for storing results 
        self.inversion_results = {
            "iteration":[],
            "phi_d":[],
            "dpred":[],
            "logsigma":[],
            "mur":[]
        }

    def endIter(self):
        """
        This is run at the end of every iteration. So here, we just append 
        the new values to our dictionary
        """
        
        # Save the data
        self.inversion_results["iteration"].append(self.opt.iter)
        self.inversion_results["phi_d"].append(self.invProb.phi_d)
        self.inversion_results["dpred"].append(self.invProb.dpred)
        self.inversion_results["logsigma"].append(self.invProb.model[0])
        self.inversion_results["mur"].append(self.invProb.model[0])
        
        if self.results_file is not None: 
            with open(f"{self.results_file}", "wb") as fp:
                pickle.dump(self.inversion_results, fp)

# %%
def create_inversion(
    key, freq, invert_mu=True, relative_error=None, noise_floor=None,
    maxIter=10, maxIterCG=30, maxIterLS=20, true_casing_inds=False, 
):
    # create the simulation
    survey = create_survey(freq)
    dobsvec = np.hstack(list(dobs_dict[key][freq].values()))
    dobs = data.Data(
        survey=survey, dobs=dobsvec, relative_error=relative_error, noise_floor=noise_floor
    )

    sim = create_simulation(survey, invert_mu, true_casing_inds)
    dmis = data_misfit.L2DataMisfit(data=dobs, simulation=sim)

    if invert_mu is True: 
        reg = regularization.Small(mesh=discretize.TensorMesh([2]))
        opt = optimization.ProjectedGNCG(
            maxIter=maxIter, lower=np.r_[-np.inf, 1], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
        )
    else: 
        reg = regularization.Small(mesh=discretize.TensorMesh([1]))
        opt = optimization.ProjectedGNCG(
            maxIter=maxIter, lower=np.r_[-np.inf], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
        )

    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt, beta=0)

    # directives
    target_misfit = directives.TargetMisfit(chifact=1)
    
    if true_casing_inds:
        filename_save = f"inv_{key}_{freq:1.0f}_{invert_mu}_true_casing.pkl"
    else: 
        filename_save = f"inv_{key}_{freq:1.0f}_{invert_mu}.pkl"
    inversion_progress = SaveInversionProgress(results_file=f"{directory}/{filename_save}")
    
    # inversion 
    inv = inversion.BaseInversion(inv_prob, [target_misfit, inversion_progress])
    
    return inv

# %% [markdown]
# # experiment 1: invert for "equivalent conductivity" of hollow casing

# %%
# inv_dict_hollow = {}
# relative_error = 0.02
# noise_floor = 1e-11

# for key in inv_keys:
#     tmp = {}
#     for freq in frequencies[freq_inds_inv]:
#         tmp[freq] = {
#             invert_mu: create_inversion(
#                 key, freq, invert_mu=invert_mu, relative_error=relative_error, noise_floor=noise_floor, 
#                 true_casing_inds=True
#             )
#             for invert_mu in [False]
#         }
#     inv_dict_hollow[key] = tmp

# %%
# mrec_dict_hollow = {}

# for key, inv_dict_freq in inv_dict_hollow.items():
#     tmp = {}
#     for freq, inv_dict_mu in inv_dict_freq.items():
#         print(f"\n\n------------------------ {key} : {freq} Hz -------------------------- \n")
#         tmp[freq] = {
#             invert_mu: inv.run(np.r_[np.log(sigma_casing)]) 
#             for invert_mu, inv in inv_dict_mu.items()
#         }
#         print(tmp[freq])
#     mrec_dict_hollow[key] = tmp

# %%
def get_inversion_result_dict(inv):
    return inv.directiveList.dList[-1].inversion_results

# %%
def plot_obs_pred(inv_dict, key, freq, invert_mu=True, ax=None, color_ind=0, label=None):
    if ax is None: 
        fig, ax = plt.subplots(3, 2, figsize=(12, 8))
    
    dobs = dobs_dict[key][freq]
    dpred = get_inversion_result_dict(inv_dict[key][freq][invert_mu])["dpred"][-1]
    
    ax[0, 0].semilogy(rx_x, np.abs(dobs["real"]), "o", color=f"C{color_ind}", label=f"{label} obs")
    ax[0, 0].semilogy(rx_x, np.abs(dpred[:len(rx_x)]), "-", color=f"C{color_ind}", label=f"{label} pred")

    ax[0, 1].semilogy(rx_x, np.abs(dobs["imag"]), "o", color=f"C{color_ind}")
    ax[0, 1].semilogy(rx_x, np.abs(dpred[len(rx_x):]), "-", color=f"C{color_ind}")

    diff = np.hstack(list(dobs.values())) - dpred
    ax[1, 0].semilogy(rx_x, np.abs(diff[:len(rx_x)]), "-", label="diff", color=f"C{color_ind}")
    ax[1, 1].semilogy(rx_x, np.abs(diff[len(rx_x):]), "-", label="diff", color=f"C{color_ind}")

    ax[2, 0].semilogy(rx_x, np.abs(diff[:len(rx_x)])/np.abs(dobs["real"])*100, "-", color=f"C{color_ind}")
    ax[2, 1].semilogy(rx_x, np.abs(diff[len(rx_x):])/np.abs(dobs["imag"])*100, "-", color=f"C{color_ind}")

    for a in ax.flatten():
        a.grid("both", alpha=0.5)
    return ax

# %%
# inv_dict_hollow.keys()

# %%
# ind_mur_plot = 4
# ind_freq_plot = 3

# fig, ax = plt.subplots(3, 2, figsize=(12, 8))

# for i, key in enumerate(list(inv_dict_hollow.keys())[1:]): 
#     label = f"{key.split('_')[1]} $\mu_0$"
#     plot_obs_pred(
#         inv_dict_hollow, key,  
#         frequencies[freq_inds_inv[ind_freq_plot]], False, 
#         ax=ax, color_ind=i, label=label
#     )
# # ax[0, 0].legend()

# %%
# fig, ax = plt.subplots(1,1) 

# for i, key in enumerate(mrec_dict_hollow.keys()):
#     for f, val in mrec_dict_hollow[key].items():
#         ax.loglog(
#             f, np.exp(val[False]), f"C{i}o", 
#             label=f"{key.split('-')[1]} $\mu_0$" if f==frequencies[freq_inds_inv[0]] else None
#         )

# %% [markdown]
# # experiment 2: invert for solid cylinder conductivity, permeability

# %%
inv_dict = {}
relative_error = 0.05
noise_floor = 1e-10

for key in inv_keys:
    tmp = {}
    for freq in frequencies[freq_inds_inv]:
        tmp[freq] = {
            invert_mu: create_inversion(
                key, freq, invert_mu=invert_mu, 
                relative_error=relative_error, noise_floor=noise_floor,
            )
            for invert_mu in [True, False]
        }
    inv_dict[key] = tmp

# %%
casing_t_inv
# Out:
# array([0.01])

# %%
t = casing_t_inv[0]
sigdc = sigma_casing * (1-(casing_b-t)**2/casing_b**2)
sigstart = sigma_casing

def get_starting_model(key, invert_mu):
    if invert_mu is False:
        return np.r_[np.log(sigstart)]
    mur = float(key.split('_')[1])
    t = float(key.split('_')[-1])
    if mur > 1:
        mustart = mur * t / casing_b
    else:
        mustart = 1
    return np.r_[np.log(sigstart), mustart]

# %%
tmp_sim = inv_dict[inv_keys[0]][frequencies[0]][True].invProb.dmisfit.simulation

# %%
inv_keys[0]
# Out:
# 'casing_1_1.00e-02'

# %%
starting_model = get_starting_model(inv_keys[0], True)
fig, ax = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)
out = mesh.plot_image(
    np.log10(tmp_sim.sigmaMap * starting_model), ax=ax[0], mirror=True
)
plt.colorbar(out[0], ax=ax[0])

out = mesh.plot_image(
    np.log10(tmp_sim.muMap * starting_model), ax=ax[1],
    mirror=True
)
plt.colorbar(out[0], ax=ax[1])

ax[0].set_xlim(0.5*np.r_[-1, 1])
ax[0].set_ylim(np.r_[-600, 20])
# Out:
# (-600.0, 20.0)

# %%
mrec_dict = {}

for key, inv_dict_freq in inv_dict.items():
    tmp = {}
    for freq, inv_dict_mu in inv_dict_freq.items():
        print(f"\n\n------------------------ {key} : {freq} Hz -------------------------- \n")
        tmp[freq] = {
            invert_mu: inv.run(get_starting_model(key, invert_mu)) 
            for invert_mu, inv in inv_dict_mu.items()
        }
        print(tmp[freq])
    mrec_dict[key] = tmp
# Out:
# ------------------------ casing_1_1.00e-02 : 0.1 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# /home/lheagy/.conda/envs/casing/lib/python3.9/site-packages/pymatsolver/direct.py:23: PardisoTypeConversionWarning: Converting csc_matrix matrix to CSR format, will slow down.
#   self.solver = MKLPardisoSolver(
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.12e+01  0.00e+00  1.12e+01    1.35e+01      0
# /home/lheagy/.conda/envs/casing/lib/python3.9/site-packages/pymatsolver/direct.py:73: PardisoTypeConversionWarning: Converting csc_matrix matrix to CSR format, will slow down.
#   self.solver.refactor(self.A)
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.2151e+00
# 1 : |xc-x_last| = 1.0339e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 1.3476e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.3476e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.12e+01  0.00e+00  1.12e+01    1.35e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.2151e+00
# 1 : |xc-x_last| = 1.0339e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 1.3476e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.3476e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([15.32156335,  1.        ]), False: array([15.32156335])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.12589254117941673 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.24e+01  0.00e+00  1.24e+01    1.49e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3416e+00
# 1 : |xc-x_last| = 2.0757e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 1.4945e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4945e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.24e+01  0.00e+00  1.24e+01    1.49e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3416e+00
# 1 : |xc-x_last| = 2.0757e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 1.4945e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4945e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([15.21738099,  1.        ]), False: array([15.21738099])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.15848931924611134 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.40e+01  0.00e+00  1.40e+01    1.68e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.4993e+00
# 1 : |xc-x_last| = 4.1674e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 1.6777e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6777e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.40e+01  0.00e+00  1.40e+01    1.68e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.4993e+00
# 1 : |xc-x_last| = 4.1674e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 1.6777e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6777e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([15.00820977,  1.        ]), False: array([15.00820977])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.19952623149688797 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.58e+01  0.00e+00  1.58e+01    1.89e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6806e+00
# 1 : |xc-x_last| = 8.3635e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 1.8886e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.8886e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.58e+01  0.00e+00  1.58e+01    1.89e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6806e+00
# 1 : |xc-x_last| = 8.3635e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 1.8886e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.8886e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58859374,  1.        ]), False: array([14.58859374])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.251188643150958 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.77e+01  0.00e+00  1.77e+01    2.11e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.8718e+00
# 1 : |xc-x_last| = 8.3882e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.1108e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.1108e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.77e+01  0.00e+00  1.77e+01    2.11e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.8718e+00
# 1 : |xc-x_last| = 8.3882e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.1108e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.1108e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58612616,  1.        ]), False: array([14.58612616])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.31622776601683794 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.96e+01  0.00e+00  1.96e+01    2.32e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0554e+00
# 1 : |xc-x_last| = 8.4073e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.3242e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.3242e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.96e+01  0.00e+00  1.96e+01    2.32e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0554e+00
# 1 : |xc-x_last| = 8.4073e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.3242e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.3242e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58422278,  1.        ]), False: array([14.58422278])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.3981071705534973 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.12e+01  0.00e+00  2.12e+01    2.51e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.2167e+00
# 1 : |xc-x_last| = 8.4211e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.5119e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.5119e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.12e+01  0.00e+00  2.12e+01    2.51e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.2167e+00
# 1 : |xc-x_last| = 8.4211e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.5119e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.5119e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58283394,  1.        ]), False: array([14.58283394])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.5011872336272724 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.25e+01  0.00e+00  2.25e+01    2.66e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.3478e+00
# 1 : |xc-x_last| = 8.4311e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.6644e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.6644e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.25e+01  0.00e+00  2.25e+01    2.66e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.3478e+00
# 1 : |xc-x_last| = 8.4311e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.6644e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.6644e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58184297,  1.        ]), False: array([14.58184297])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.6309573444801934 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.35e+01  0.00e+00  2.35e+01    2.78e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4476e+00
# 1 : |xc-x_last| = 8.4379e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.7805e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.7805e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.35e+01  0.00e+00  2.35e+01    2.78e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4476e+00
# 1 : |xc-x_last| = 8.4379e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.7805e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.7805e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.581156,  1.      ]), False: array([14.581156])}
#
#
# ------------------------ casing_1_1.00e-02 : 0.7943282347242815 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.42e+01  0.00e+00  2.42e+01    2.86e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5200e+00
# 1 : |xc-x_last| = 8.4425e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.8647e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.8647e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.42e+01  0.00e+00  2.42e+01    2.86e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5200e+00
# 1 : |xc-x_last| = 8.4425e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.8647e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.8647e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58069524,  1.        ]), False: array([14.58069524])}
#
#
# ------------------------ casing_1_1.00e-02 : 1.0 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.47e+01  0.00e+00  2.47e+01    2.92e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5709e+00
# 1 : |xc-x_last| = 8.4457e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.9238e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9238e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.47e+01  0.00e+00  2.47e+01    2.92e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5709e+00
# 1 : |xc-x_last| = 8.4457e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.9238e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9238e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58038118,  1.        ]), False: array([14.58038118])}
#
#
# ------------------------ casing_1_1.00e-02 : 1.2589254117941675 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.51e+01  0.00e+00  2.51e+01    2.96e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6061e+00
# 1 : |xc-x_last| = 8.4478e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.9647e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9647e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.51e+01  0.00e+00  2.51e+01    2.96e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6061e+00
# 1 : |xc-x_last| = 8.4478e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.9647e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9647e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58016432,  1.        ]), False: array([14.58016432])}
#
#
# ------------------------ casing_1_1.00e-02 : 1.584893192461114 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.53e+01  0.00e+00  2.53e+01    2.99e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6303e+00
# 1 : |xc-x_last| = 8.4494e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.9928e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9928e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.53e+01  0.00e+00  2.53e+01    2.99e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6303e+00
# 1 : |xc-x_last| = 8.4494e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.9928e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9928e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58000559,  1.        ]), False: array([14.58000559])}
#
#
# ------------------------ casing_1_1.00e-02 : 1.9952623149688797 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.55e+01  0.00e+00  2.55e+01    3.01e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6469e+00
# 1 : |xc-x_last| = 8.4507e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 3.0120e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0120e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.55e+01  0.00e+00  2.55e+01    3.01e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6469e+00
# 1 : |xc-x_last| = 8.4507e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 3.0120e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0120e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.57987887,  1.        ]), False: array([14.57987887])}
#
#
# ------------------------ casing_1_1.00e-02 : 2.511886431509581 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.56e+01  0.00e+00  2.56e+01    3.02e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6576e+00
# 1 : |xc-x_last| = 8.4518e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 3.0242e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0242e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.56e+01  0.00e+00  2.56e+01    3.02e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6576e+00
# 1 : |xc-x_last| = 8.4518e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 3.0242e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0242e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.57976811,  1.        ]), False: array([14.57976812])}
#
#
# ------------------------ casing_1_1.00e-02 : 3.1622776601683795 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.56e+01  0.00e+00  2.56e+01    3.03e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6625e+00
# 1 : |xc-x_last| = 8.4529e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 3.0296e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0296e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.56e+01  0.00e+00  2.56e+01    3.03e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6625e+00
# 1 : |xc-x_last| = 8.4529e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 3.0296e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0296e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.57966247,  1.        ]), False: array([14.57966248])}
#
#
# ------------------------ casing_1_1.00e-02 : 3.981071705534973 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.56e+01  0.00e+00  2.56e+01    3.03e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6602e+00
# 1 : |xc-x_last| = 8.4539e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 3.0264e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0264e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.56e+01  0.00e+00  2.56e+01    3.03e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6602e+00
# 1 : |xc-x_last| = 8.4539e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 3.0264e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0264e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.57955612,  1.        ]), False: array([14.57955611])}
#
#
# ------------------------ casing_1_1.00e-02 : 5.011872336272725 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.55e+01  0.00e+00  2.55e+01    3.01e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6465e+00
# 1 : |xc-x_last| = 8.4550e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 3.0097e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0097e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.55e+01  0.00e+00  2.55e+01    3.01e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6465e+00
# 1 : |xc-x_last| = 8.4550e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 3.0097e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0097e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.57945269,  1.        ]), False: array([14.57945269])}
#
#
# ------------------------ casing_1_1.00e-02 : 6.309573444801933 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.51e+01  0.00e+00  2.51e+01    2.97e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6142e+00
# 1 : |xc-x_last| = 8.4558e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.9711e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9711e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.51e+01  0.00e+00  2.51e+01    2.97e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6142e+00
# 1 : |xc-x_last| = 8.4558e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.9711e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9711e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.57936944,  1.        ]), False: array([14.57936944])}
#
#
# ------------------------ casing_1_1.00e-02 : 7.943282347242818 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.45e+01  0.00e+00  2.45e+01    2.90e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5515e+00
# 1 : |xc-x_last| = 8.4559e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.8966e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.8966e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.45e+01  0.00e+00  2.45e+01    2.90e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5515e+00
# 1 : |xc-x_last| = 8.4559e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.8966e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.8966e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.57936297,  1.        ]), False: array([14.57936298])}
#
#
# ------------------------ casing_1_1.00e-02 : 10.0 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.34e+01  0.00e+00  2.34e+01    2.77e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4404e+00
# 1 : |xc-x_last| = 8.4538e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.7655e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.7655e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.34e+01  0.00e+00  2.34e+01    2.77e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4404e+00
# 1 : |xc-x_last| = 8.4538e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.7655e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.7655e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.57956416,  1.        ]), False: array([14.57956426])}
#
#
# ------------------------ casing_1_1.00e-02 : 12.589254117941675 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.16e+01  0.00e+00  2.16e+01    2.55e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.2574e+00
# 1 : |xc-x_last| = 8.4462e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.5505e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.5505e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.16e+01  0.00e+00  2.16e+01    2.55e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.2574e+00
# 1 : |xc-x_last| = 8.4462e-01 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 2.5505e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.5505e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# {True: array([14.58032558,  1.        ]), False: array([14.58032558])}
#
#
# ------------------------ casing_1_1.00e-02 : 15.848931924611142 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.88e+01  0.00e+00  1.88e+01    2.22e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.9782e+00
# 1 : |xc-x_last| = 8.4257e-01 <= tolX*(1+|x0|) = 1.6457e+00
# 0 : |proj(x-g)-x|    = 2.2236e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.2236e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# ...
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.53e+02  0.00e+00  2.53e+02    2.45e+02      0
#    1  0.00e+00  2.20e+01  1.21e+03  2.20e+01    8.25e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5382e+01
# 1 : |xc-x_last| = 4.7289e-01 <= tolX*(1+|x0|) = 4.3871e+00
# 0 : |proj(x-g)-x|    = 8.2462e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.2462e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.18e+03  0.00e+00  1.18e+03    2.15e+01      0
#    1  0.00e+00  1.17e+03  5.21e-01  1.17e+03    1.31e+01      0
#    2  0.00e+00  1.17e+03  6.32e-01  1.17e+03    1.15e+01      0   Skip BFGS
#    3  0.00e+00  1.16e+03  7.22e-01  1.16e+03    1.01e+01      0   Skip BFGS
#    4  0.00e+00  1.16e+03  7.98e-01  1.16e+03    9.03e+00      0   Skip BFGS
#    5  0.00e+00  1.16e+03  8.62e-01  1.16e+03    8.11e+00      0   Skip BFGS
#    6  0.00e+00  1.16e+03  9.19e-01  1.16e+03    7.35e+00      0   Skip BFGS
#    7  0.00e+00  1.16e+03  9.69e-01  1.16e+03    6.71e+00      0   Skip BFGS
#    8  0.00e+00  1.16e+03  1.01e+00  1.16e+03    6.16e+00      0   Skip BFGS
#    9  0.00e+00  1.16e+03  1.05e+00  1.16e+03    5.69e+00      0   Skip BFGS
#   10  0.00e+00  1.16e+03  1.09e+00  1.16e+03    5.28e+00      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.3594e-01 <= tolF*(1+|f0|) = 1.1858e+02
# 1 : |xc-x_last| = 2.4782e-02 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 5.2837e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.2837e+00 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# {True: array([ 14.74352766, 109.69726373]), False: array([13.94905326])}
#
#
# ------------------------ casing_200_1.00e-02 : 39.810717055349734 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.21e+03  0.00e+00  1.21e+03    9.97e+02      0
#    1  0.00e+00  1.92e+02  1.63e+03  1.92e+02    3.72e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.2074e+02
# 0 : |xc-x_last| = 5.9932e+01 <= tolX*(1+|x0|) = 4.3871e+00
# 0 : |proj(x-g)-x|    = 3.7244e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.7244e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.22e+03  0.00e+00  6.22e+03    8.22e+02      0
#    1  0.00e+00  5.99e+03  9.85e-01  5.99e+03    2.46e+02      2
#    2  0.00e+00  3.48e+03  8.50e+02  3.48e+03    2.58e-07      0
# ------------------------- STOP! -------------------------
# 0 : |fc-fOld| = 2.5097e+03 <= tolF*(1+|f0|) = 6.2222e+02
# 0 : |xc-x_last| = 4.2637e+01 <= tolX*(1+|x0|) = 1.6425e+00
# 1 : |proj(x-g)-x|    = 2.5826e-07 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.5826e-07 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# {True: array([ 15.39738018, 180.70203046]), False: array([-25.8084772])}
#
#
# ------------------------ casing_200_1.00e-02 : 50.11872336272725 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  9.24e+01  0.00e+00  9.24e+01    8.54e+01      0
#    1  0.00e+00  1.90e+01  1.90e+03  1.90e+01    5.71e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.3395e+00
# 0 : |xc-x_last| = 5.4669e+01 <= tolX*(1+|x0|) = 4.3871e+00
# 0 : |proj(x-g)-x|    = 5.7109e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.7109e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.16e+02  0.00e+00  4.16e+02    1.27e+01      0
#    1  0.00e+00  4.16e+02  1.49e-02  4.16e+02    2.61e+00      0
#    2  0.00e+00  4.16e+02  6.78e-03  4.16e+02    1.68e+00      0
#    3  0.00e+00  4.16e+02  1.09e-02  4.16e+02    7.55e-01      0
#    4  0.00e+00  4.16e+02  8.74e-03  4.16e+02    4.13e-01      0
#    5  0.00e+00  4.16e+02  9.83e-03  4.16e+02    2.06e-01      0
#    6  0.00e+00  4.16e+02  9.27e-03  4.16e+02    1.08e-01      0
#    7  0.00e+00  4.16e+02  9.55e-03  4.16e+02    5.49e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 5.5348e-05 <= tolF*(1+|f0|) = 4.1735e+01
# 1 : |xc-x_last| = 2.0987e-03 <= tolX*(1+|x0|) = 1.6425e+00
# 1 : |proj(x-g)-x|    = 5.4929e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.4929e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      7
# ------------------------- DONE! -------------------------
# {True: array([ 15.36683876, 181.81577509]), False: array([15.56318644])}
#
#
# ------------------------ casing_200_1.00e-02 : 63.095734448019364 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.04e+02  0.00e+00  1.04e+02    1.20e+02      0
#    1  0.00e+00  4.62e+01  2.60e+03  4.62e+01    1.05e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0533e+01
# 1 : |xc-x_last| = 8.5063e-01 <= tolX*(1+|x0|) = 4.3871e+00
# 0 : |proj(x-g)-x|    = 1.0493e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0493e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.45e+02  0.00e+00  4.45e+02    8.59e+01      0
#    1  0.00e+00  4.39e+02  4.37e+00  4.39e+02    5.38e+02      1
#    2  0.00e+00  2.08e+02  2.59e+00  2.08e+02    1.25e+02      0
#    3  0.00e+00  1.94e+02  2.16e+00  1.94e+02    2.30e+01      0   Skip BFGS
#    4  0.00e+00  1.93e+02  2.08e+00  1.93e+02    3.73e+00      0   Skip BFGS
#    5  0.00e+00  1.93e+02  2.06e+00  1.93e+02    5.82e-01      0   Skip BFGS
#    6  0.00e+00  1.93e+02  2.06e+00  1.93e+02    9.00e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.7703e-04 <= tolF*(1+|f0|) = 4.4597e+01
# 1 : |xc-x_last| = 1.1225e-03 <= tolX*(1+|x0|) = 1.6425e+00
# 1 : |proj(x-g)-x|    = 8.9978e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.9978e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      6
# ------------------------- DONE! -------------------------
# {True: array([ 15.12622889, 142.05048821]), False: array([13.39585349])}
#
#
# ------------------------ casing_200_1.00e-02 : 79.43282347242821 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.29e+02  0.00e+00  1.29e+02    1.33e+02      0
#    1  0.00e+00  7.03e+01  3.43e+03  7.03e+01    1.05e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3037e+01
# 0 : |xc-x_last| = 4.3854e+01 <= tolX*(1+|x0|) = 4.3871e+00
# 0 : |proj(x-g)-x|    = 1.0480e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0480e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  5.38e+02  0.00e+00  5.38e+02    6.41e+01      0
#    1  0.00e+00  2.06e+02  3.62e+00  2.06e+02    2.35e+01      2
#    2  0.00e+00  2.05e+02  3.73e+00  2.05e+02    7.46e+00      0   Skip BFGS
#    3  0.00e+00  2.05e+02  3.77e+00  2.05e+02    2.39e+00      0   Skip BFGS
#    4  0.00e+00  2.05e+02  3.78e+00  2.05e+02    7.69e-01      0   Skip BFGS
#    5  0.00e+00  2.05e+02  3.78e+00  2.05e+02    2.47e-01      0   Skip BFGS
#    6  0.00e+00  2.05e+02  3.78e+00  2.05e+02    7.95e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 7.0611e-05 <= tolF*(1+|f0|) = 5.3937e+01
# 1 : |xc-x_last| = 4.3214e-04 <= tolX*(1+|x0|) = 1.6425e+00
# 1 : |proj(x-g)-x|    = 7.9519e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.9519e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      6
# ------------------------- DONE! -------------------------
# {True: array([ 15.29981337, 201.05463678]), False: array([12.67394886])}
#
#
# ------------------------ casing_200_1.00e-02 : 100.0 Hz --------------------------
#
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.72e+02  0.00e+00  1.72e+02    1.49e+02      0
#    1  0.00e+00  8.59e+01  4.09e+03  8.59e+01    9.91e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.7269e+01
# 0 : |xc-x_last| = 4.6310e+01 <= tolX*(1+|x0|) = 4.3871e+00
# 0 : |proj(x-g)-x|    = 9.9065e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 9.9065e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# SimPEG.InvProblem will set Regularization.mref to m0.
#
#         SimPEG.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#         ***Done using same Solver and solverOpts as the problem***
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.64e+02  0.00e+00  6.64e+02    5.35e+01      0
#    1  0.00e+00  5.92e+02  3.33e+00  5.92e+02    7.99e+01      2
#    2  0.00e+00  5.82e+02  2.96e+00  5.82e+02    5.31e+01      0
#    3  0.00e+00  5.77e+02  2.69e+00  5.77e+02    3.38e+01      0   Skip BFGS
#    4  0.00e+00  5.75e+02  2.50e+00  5.75e+02    2.09e+01      0   Skip BFGS
#    5  0.00e+00  5.74e+02  2.38e+00  5.74e+02    1.28e+01      0   Skip BFGS
#    6  0.00e+00  5.74e+02  2.30e+00  5.74e+02    7.70e+00      0   Skip BFGS
#    7  0.00e+00  5.73e+02  2.25e+00  5.73e+02    4.62e+00      0   Skip BFGS
#    8  0.00e+00  5.73e+02  2.22e+00  5.73e+02    2.76e+00      0   Skip BFGS
#    9  0.00e+00  5.73e+02  2.20e+00  5.73e+02    1.65e+00      0   Skip BFGS
#   10  0.00e+00  5.73e+02  2.19e+00  5.73e+02    9.81e-01      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 6.8827e-03 <= tolF*(1+|f0|) = 6.6516e+01
# 1 : |xc-x_last| = 5.2433e-03 <= tolX*(1+|x0|) = 1.6425e+00
# 0 : |proj(x-g)-x|    = 9.8089e-01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 9.8089e-01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# {True: array([ 15.19853759, 214.12062518]), False: array([13.33204389])}

# %%
fig, ax = plt.subplots(1,1) 

for i, key in enumerate(list(mrec_dict.keys())[:1]):
    for f, val in mrec_dict[key].items():
        ax.loglog(
            f, np.exp(val[False]), f"C{i}o", 
            label=f"{key.split('-')[1]} $\mu_0$" if f==frequencies[freq_inds_inv[0]] else None
        )
ax.loglog(frequencies, np.ones_like(frequencies)*sigdc, 'k-')
ax.loglog(frequencies, np.ones_like(frequencies)*sigma_casing, 'k-')

# ax.set_ylim(1e5, 1e9)

# %%
sigdc
# Out:
# 1800000.0000000005

# %%
fig, ax = plt.subplots(1,1) 

for i, key in enumerate(mrec_dict.keys()):
    for f, val in mrec_dict[key].items():
        ax.loglog(
            f, np.exp(val[True][0]), f"C{i}o", 
            label=f"{key.split('-')[1]} $\mu_0$" if f==frequencies[freq_inds_inv[0]] else None
        )
ax.loglog(frequencies, np.ones_like(frequencies)*sigdc, 'k-')
ax.loglog(frequencies, np.ones_like(frequencies)*sigma_casing, 'k-')
ax.grid("both", alpha=0.5)
# ax.set_ylim(1e6, 3e6)

# %%
fig, ax = plt.subplots(1,1) 

for i, key in enumerate(mrec_dict.keys()):
    for f, val in mrec_dict[key].items():
        ax.semilogx(
            f, (val[True][1]), f"C{i}o", 
            label=f"{key.split('-')[1]} $\mu_0$" if f==frequencies[freq_inds_inv[0]] else None
        )
ax.grid("both")
ax.set_ylim(0, 50)
# ax.set_xli)
# Out:
# (0.0, 50.0)

# %%
for mur in mur_inv[1:]:
    print(f"mur: {mur:4.0f}:    {mur * t / casing_b:3.2f}")
# Out:
# mur:   50:    10.00
# mur:  100:    20.00
# mur:  150:    30.00
# mur:  200:    40.00

# %%
def skin_depth_freq(delta, sigma, mur):
    return 2 / (2*np.pi * delta**2 * mur* mu_0 * sigma)

# %%
for mur in mur_inv:
    print(f"{mur:4.0f} mu0:  {skin_depth_freq(casing_t_inv[0], sigma_casing, mur):5.1f} Hz")
# Out:
#    1 mu0:  506.6 Hz
#   50 mu0:   10.1 Hz
#  100 mu0:    5.1 Hz
#  150 mu0:    3.4 Hz
#  200 mu0:    2.5 Hz
